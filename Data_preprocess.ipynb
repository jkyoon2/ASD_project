# %% [markdown]
# # NAME: 정경윤
# # ID: 2019162029
# # Project : ASD fMRI detection
# ***
# # <font color='royalblue'>Data Preprocessing</font>

# %% [markdown]
# ## <font color='royalblue'> Part 1. nii 파일 열기 </font>
#
# ### **Aims**:
# 신경 영상 데이터 확장자 nii 파일 열기

# %%
# nifti 이미지 읽기
from nilearn import plotting
from nilearn.image import mean_img

import nibabel as nib

img = nib.load('/Users/jungkyungyoon/Desktop/fMRI ASD 진단 플젝/데이터/Outputs/cpac/nofilt_noglobal/reho/Caltech_0051456_reho.nii.gz')
img_data=nib.Nifti1Image(img.get_fdata(), img.affine)

plotting.view_img(mean_img(img_data), threshold=None)
# Out:
# /Users/jungkyungyoon/Desktop/fMRI ASD 진단 플젝/ASDproject/lib/python3.10/site-packages/numpy/core/fromnumeric.py:771: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
# ...
